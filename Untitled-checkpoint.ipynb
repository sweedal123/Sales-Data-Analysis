# %%
import pandas as pd

# %%
df = pd.read_csv("superstore.csv")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0    6827  CA-2016-118689  10-02-2016  10-09-2016  Standard Class    TC-20980
# 1    8154  CA-2017-140151   3/23/2017   3/25/2017     First Class    RB-19360
# 2    4191  CA-2017-166709  11/17/2017  11/22/2017  Standard Class    HL-15040
# 3    9040  CA-2016-117121  12/17/2016  12/21/2016  Standard Class    AB-10105
# 4    4099  CA-2014-116904   9/23/2014   9/28/2014  Standard Class    SC-20095
#
#    Customer Name    Segment        Country         City  ... Postal Code  \
# 0   Tamara Chand  Corporate  United States    Lafayette  ...       47905
# 1   Raymond Buch   Consumer  United States      Seattle  ...       98115
# 2   Hunter Lopez   Consumer  United States       Newark  ...       19711
# 3  Adrian Barton   Consumer  United States      Detroit  ...       48205
# 4   Sanjit Chand   Consumer  United States  Minneapolis  ...       55407
#
#     Region       Product ID         Category Sub-Category  \
# 0  Central  TEC-CO-10004722       Technology      Copiers
# 1     West  TEC-CO-10004722       Technology      Copiers
# 2     East  TEC-CO-10004722       Technology      Copiers
# 3  Central  OFF-BI-10000545  Office Supplies      Binders
# 4  Central  OFF-BI-10001120  Office Supplies      Binders
#
#                                        Product Name     Sales  Quantity  \
# 0             Canon imageCLASS 2200 Advanced Copier  17499.95         5
# 1             Canon imageCLASS 2200 Advanced Copier  13999.96         4
# 2             Canon imageCLASS 2200 Advanced Copier  10499.97         3
# 3  GBC Ibimaster 500 Manual ProClick Binding System   9892.74        13
# 4              Ibico EPK-21 Electric Binding System   9449.95         5
#
#    Discount     Profit
# 0       0.0  8399.9760
# 1       0.0  6719.9808
# 2       0.0  5039.9856
# 3       0.0  4946.3700
# 4       0.0  4630.4755
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), str(15)
# memory usage: 1.6 MB

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.groupby("Category")["Sales"].sum()
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
df.groupby("Region")["Profit"].sum()
# Out:
# Region
# Central     39706.3625
# East        91522.7800
# South       46749.4303
# West       108418.4489
# Name: Profit, dtype: float64

# %%
df.groupby("Product Name")["Sales"].sum().sort_values(ascending=False).head(10)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
df.to_csv("superstore_cleaned.csv", index=False)
